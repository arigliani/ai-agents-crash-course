# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv

import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant that provides nutrition advice. 
    You give concise answers.
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Overall, yes—bananas are healthy as part of a balanced diet.
#
#     Key points:
#     - Nutrients: potassium (~400 mg), vitamin B6, vitamin C, fiber (about 3 g), moderate carbs and calories (~105 kcal for a medium banana).
#     - Benefits: supports heart health, digestion, and energy; convenient, portable snack.
#     - Considerations: contains natural sugars; portion matters for blood sugar management; not a complete nutrient source on its own.
#
#     Bottom line: a nutritious, convenient fruit to include regularly, in moderation.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are quite healthy in moderation.
#
# Key points:
# - Nutrients: potassium, vitamin B6, vitamin C, fiber, and some resistant starch.
# - Benefits: supports heart health, digestion, and steady energy.
# - Considerations: natural sugars; portion size matters for those watching blood sugar.
# - Quick facts: a medium banana ~105 calories, about 422 mg potassium.
#
# Overall: a nutritious, convenient fruit—great as part of a balanced diet.

# %% [markdown]
# _Good Job!_
